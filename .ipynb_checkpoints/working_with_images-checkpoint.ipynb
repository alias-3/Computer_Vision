# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
imginv = cv2.imread('penguin.jpg')
img = cv2.cvtColor(imginv,cv2.COLOR_BGR2RGB)
#cv2.imshow('test',img)
#cv2.waitKey(0)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
#cv2.imshow('gray',gray)
#cv2.waitKey(0)
plt.imshow(gray,cmap='gray')

# %%
print(gray[300,300])
# Out:
# 231

# %%
print(np.amax(gray))
print(np.amin(gray))
# Out:
# 251
# 2

# %%
red = img[:,:,0]
green = img[:,:,1]
blue = img[:,:,2]
plt.imshow(red)

# %%
plt.imshow(green)

# %%
plt.imshow(blue)

# %%
image = mpimg.imread('car_green_screen.jpg')

# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)
# Out:
# Image dimensions: (450, 660, 3)

# %%
plt.imshow(image)

# %%
lower_green = np.array([0,180,0]) 
upper_green = np.array([100,255,100])
mask = cv2.inRange(image, lower_green, upper_green)
plt.imshow(mask, cmap='gray')

# %%
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]
plt.imshow(masked_image)

# %%
background_image = mpimg.imread('sky.jpg')

background_image = background_image[0:450,0:660]
plt.imshow(background_image)
bgimage = np.copy(background_image)
bgimage[mask==0] = [0,0,0]

plt.imshow(bgimage)

# %%
final = bgimage + masked_image
plt.imshow(final)

# %%
image = mpimg.imread('images/car_green_screen2.jpg')

plt.imshow(image)
